# %%
import pandas as pd

# %%
df_train = pd.read_csv("../../data/unsw-nb15/processed/train.csv")
df_test = pd.read_csv("../../data/unsw-nb15/processed/test.csv")

# %%
df_train.head()
# Out:
#         dur     spkts     dpkts    sbytes    dbytes      rate      sttl  \
# 0  0.002025  0.000520  0.000364  0.000018  0.000012  0.000074  0.988235
# 1  0.010832  0.001352  0.003463  0.000054  0.002867  0.000078  0.243137
# 2  0.027052  0.000728  0.001458  0.000026  0.000900  0.000014  0.243137
# 3  0.028027  0.001144  0.001093  0.000046  0.000053  0.000014  0.243137
# 4  0.007491  0.000936  0.000547  0.000039  0.000018  0.000033  0.996078
#
#        dttl         sload     dload  ...  proto:vmtp  proto:vrrp  \
# 0  1.000000  2.364553e-06  0.000379  ...       False       False
# 1  0.992126  1.401989e-06  0.022458  ...       False       False
# 2  0.992126  2.625704e-07  0.002717  ...       False       False
# 3  0.992126  4.576117e-07  0.000150  ...       False       False
# 4  0.992126  1.429776e-06  0.000178  ...       False       False
#
#    proto:wb-expak  proto:wb-mon  proto:wsn  proto:xnet  proto:xns-idp  \
# ...

# %%
df_test.head()
# Out:
#             dur     spkts  dpkts    sbytes  dbytes      rate      sttl  dttl  \
# 0  1.833334e-07  0.000104    0.0  0.000036     0.0  0.090909  0.996078   0.0
# 1  1.333334e-07  0.000104    0.0  0.000134     0.0  0.125000  0.996078   0.0
# 2  8.333335e-08  0.000104    0.0  0.000080     0.0  0.200000  0.996078   0.0
# 3  1.000000e-07  0.000104    0.0  0.000067     0.0  0.166667  0.996078   0.0
# 4  1.666667e-07  0.000104    0.0  0.000162     0.0  0.100000  0.996078   0.0
#
#       sload  dload  ...  proto:vmtp  proto:vrrp  proto:wb-expak  proto:wb-mon  \
# 0  0.030121    0.0  ...       False       False           False         False
# 1  0.147128    0.0  ...       False       False           False         False
# 2  0.142685    0.0  ...       False       False           False         False
# 3  0.100200    0.0  ...       False       False           False         False
# 4  0.142017    0.0  ...       False       False           False         False
#
# ...

# %%
print("Training Set Shape:", df_train.shape)
print("Testing Set Shape:", df_test.shape)
# Out:
# Training Set Shape: (175319, 197)
# Testing Set Shape: (82328, 197)
